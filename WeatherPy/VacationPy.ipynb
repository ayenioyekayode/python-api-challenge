# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install pyproj
# Out:
# Requirement already satisfied: pyproj in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pyproj) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (1.11.1)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.3.4)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.18.3)
# Requirement already satisfied: packaging in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (23.2)
# Requirement already satisfied: numpy in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.26.3)
# Requirement already satisfied: shapely in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (2.0.3)
# Requirement already satisfied: param in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: panel>=1.0.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (1.3.8)
# Requirement already satisfied: pyproj in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from geoviews) (2023.10.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.3)
# Requirement already satisfied: contourpy>=1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.1.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: colorcet in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: markdown in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (3.5.2)
# Requirement already satisfied: markdown-it-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (0.4.0)
# Requirement already satisfied: requests in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.2)
# Requirement already satisfied: bleach in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=1.0.0->geoviews) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pyproj->geoviews) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cartopy
# Out:
# Requirement already satisfied: cartopy in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (1.26.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.8.2)
# Requirement already satisfied: shapely>=1.7 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (2.0.3)
# Requirement already satisfied: packaging>=20 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pyproj>=3.1.0->cartopy) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hvplot
# Out:
# Requirement already satisfied: hvplot in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (0.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (3.3.4)
# Requirement already satisfied: colorcet>=2 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.18.3)
# Requirement already satisfied: pandas in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (2.1.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.26.3)
# Requirement already satisfied: packaging in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (23.2)
# Requirement already satisfied: panel>=0.11.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (1.3.8)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from hvplot) (2.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.3)
# Requirement already satisfied: contourpy>=1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bokeh>=1.0.0->hvplot) (2023.10.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pandas->hvplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (3.5.2)
# Requirement already satisfied: markdown-it-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (0.4.0)
# Requirement already satisfied: requests in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.2)
# Requirement already satisfied: bleach in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from panel>=0.11.0->hvplot) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayeni\anaconda3\envs\dev\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.2.2)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0                 ushuaia -54.8000  -68.3000     13.81        72
# 1        1  hawaiian paradise park  19.5933 -154.9731     22.80        96
# 2        2                 iqaluit  63.7506  -68.5145    -25.73        62
# 3        3             west island -12.1568   96.8225     28.20        74
# 4        4               polyarnyy  69.1989   33.4478     -3.77        86
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.14      AR  1709064771
# 1         100        3.09      US  1709064893
# 2         100        1.79      CA  1709064893
# 3          87        6.31      CC  1709064893
# 4          92        5.79      RU  1709064894

# %% [markdown]
#  Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0                 ushuaia -54.8000  -68.3000     13.81        72
# 1        1  hawaiian paradise park  19.5933 -154.9731     22.80        96
# 2        2                 iqaluit  63.7506  -68.5145    -25.73        62
# 3        3             west island -12.1568   96.8225     28.20        74
# 4        4               polyarnyy  69.1989   33.4478     -3.77        86
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.14      AR  1709064771
# 1         100        3.09      US  1709064893
# 2         100        1.79      CA  1709064893
# 3          87        6.31      CC  1709064893
# 4          92        5.79      RU  1709064894

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
weather_filtered_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 17        17        saipan  15.1355  145.7010     24.39        78           0
# 312      312     taoudenni  22.6783   -3.9836     26.96         9           0
# 313      313    port sudan  19.6175   37.2164     23.31        58           0
# 318      318         aiken  33.5835  -81.5998     21.59        62           0
# 337      337       mangrol  21.1167   70.1167     23.73        49           0
# 356      356         ubari  26.5921   12.7805     23.06        11           0
# 431      431      adilabad  19.6667   78.5333     25.90        42           0
# 461      461   al khaburah  23.9886   57.0984     22.33        70           0
# 510      510       konarka  19.9000   86.1167     24.22        69           0
# 545      545  paradip garh  20.3167   86.6167     23.16        68           0
# 569      569   as sulayyil  20.4607   45.5779     21.14        39           2
#
#      Wind Speed Country        Date
# 17         3.60      MP  1709064896
# 312        4.21      ML  1709064974
# 313        2.18      SD  1709064974
# 318        3.60      US  1709064906
# 337        3.47      IN  1709064978
# 356        2.57      LY  1709064982
# 431        1.21      IN  1709064998
# 461        1.98      OM  1709065004
# 510        0.20      IN  1709065012
# 545        1.72      IN  1709065021
# 569        4.38      SA  1709065038

# %%
# Narrow down cities that fit criteria and drop any results with null values
weather_filtered_df = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                       & (city_data_df["Max Temp"] > 21) 
                                       & (city_data_df["Cloudiness"] < 3)
                                       & (city_data_df["Wind Speed"] < 4.5)]

# Drop any rows with null values
weather_filtered_df.dropna()


# Display sample data
weather_filtered_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 17        17        saipan  15.1355  145.7010     24.39        78           0
# 312      312     taoudenni  22.6783   -3.9836     26.96         9           0
# 313      313    port sudan  19.6175   37.2164     23.31        58           0
# 318      318         aiken  33.5835  -81.5998     21.59        62           0
# 337      337       mangrol  21.1167   70.1167     23.73        49           0
# 356      356         ubari  26.5921   12.7805     23.06        11           0
# 431      431      adilabad  19.6667   78.5333     25.90        42           0
# 461      461   al khaburah  23.9886   57.0984     22.33        70           0
# 510      510       konarka  19.9000   86.1167     24.22        69           0
# 545      545  paradip garh  20.3167   86.6167     23.16        68           0
# 569      569   as sulayyil  20.4607   45.5779     21.14        39           2
#
#      Wind Speed Country        Date
# 17         3.60      MP  1709064896
# 312        4.21      ML  1709064974
# 313        2.18      SD  1709064974
# 318        3.60      US  1709064906
# 337        3.47      IN  1709064978
# 356        2.57      LY  1709064982
# 431        1.21      IN  1709064998
# 461        1.98      OM  1709065004
# 510        0.20      IN  1709065012
# 545        1.72      IN  1709065021
# 569        4.38      SA  1709065038

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = weather_filtered_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 17         saipan      MP  15.1355  145.7010        78
# 312     taoudenni      ML  22.6783   -3.9836         9
# 313    port sudan      SD  19.6175   37.2164        58
# 318         aiken      US  33.5835  -81.5998        62
# 337       mangrol      IN  21.1167   70.1167        49
# 356         ubari      LY  26.5921   12.7805        11
# 431      adilabad      IN  19.6667   78.5333        42
# 461   al khaburah      OM  23.9886   57.0984        70
# 510       konarka      IN  19.9000   86.1167        69
# 545  paradip garh      IN  20.3167   86.6167        68
# 569   as sulayyil      SA  20.4607   45.5779        39

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
     longitude = row["Lng"]
     latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
params["filter"] =  f"circle:{longitude},{latitude},{radius}"
params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
name_address =  requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# as sulayyil - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity      Hotel Name
# 17         saipan      MP  15.1355  145.7010        78
# 312     taoudenni      ML  22.6783   -3.9836         9
# 313    port sudan      SD  19.6175   37.2164        58
# 318         aiken      US  33.5835  -81.5998        62
# 337       mangrol      IN  21.1167   70.1167        49
# 356         ubari      LY  26.5921   12.7805        11
# 431      adilabad      IN  19.6667   78.5333        42
# 461   al khaburah      OM  23.9886   57.0984        70
# 510       konarka      IN  19.9000   86.1167        69
# 545  paradip garh      IN  20.3167   86.6167        68
# 569   as sulayyil      SA  20.4607   45.5779        39  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )


# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
